# %% [markdown]
# ## Analysis Notebook
# ## This visualizes the regression results from STATA.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

os.chdir("C:/Users/JinfengLIU/Documents/100_Research/education-wage-analysis")

# %%
data = pd.read_csv('data/raw/data.csv')
plt.scatter(data['Unemployment'], data['GDP'])
plt.xlabel('Unemployment Rate')
plt.ylabel('GDP')
plt.title('GDP vs Unemployment')
plt.show()
plt.savefig('output/figures/gdp_scatter.png')
